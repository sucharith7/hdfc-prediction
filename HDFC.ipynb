# %% [markdown]
# # This is the model done for  hackathon competetion for hdfc data in hackerearth and secured 295 rank in hacker earth

# %% [markdown]
# # import the libraries required for to built the model

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn import datasets
import pandas as pd
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix

# %matplotlib inline

# %%
#load the train data
bdata=pd.read_csv('Train.csv')
# Out:
# C:\Users\bunny\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (746,835) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bdata.head()
# Out:
#         Col1  Col2          Col3          Col4          Col5          Col6  \
# 0    RIGHGSN     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04
# 1  RIMHI5ZGP     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05
# 2  RIHOG1SZU     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07
# 3  RIHOLMQWU     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05
# 4  RIHO584ET     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06
#
#            Col7          Col8          Col9         Col10  ...  Col2388  \
# 0  5.273655e+03  2.346153e+04  1.285597e+04  2.871509e+04  ...        0
# 1  2.154519e+05  1.923615e+05  1.726538e+05  1.666974e+05  ...        0
# 2  1.879882e+07  1.514035e+07  5.320778e+06  6.906324e+06  ...        0
# 3  8.257254e+05  7.605803e+05  3.577134e+05  4.236612e+05  ...        0
# 4  2.583183e+06  2.086546e+06  5.938358e+06  5.446532e+06  ...        0
#
#    Col2389  Col2390  Col2391  Col2392  Col2393  Col2394  Col2395  Col2396  \
# ...

# %%
#load the test data
testdata=pd.read_csv('Test.csv')
# Out:
# C:\Users\bunny\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (700,731,740,752,761,789,811,820,829,841,850) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
testdata.head()
# Out:
#         Col1          Col3          Col4          Col5          Col6  \
# 0  RIGD58ZWD  8.167140e+04  8.614542e+04  7.532296e+04  7.532296e+04
# 1  RIH660YDS -1.362824e+07 -4.493043e+06 -3.777257e+06 -4.493043e+06
# 2  RIH660Q96  1.302700e+06  1.341449e+06  1.240085e+06  1.341449e+06
# 3  RIYDO15W1  1.932258e+05  1.454433e+05  1.929148e+05  1.454433e+05
# 4  RIYBGC1ZD  3.913385e+05  1.987337e+05  1.703432e+05  1.987337e+05
#
#            Col7          Col8          Col9         Col10         Col11  ...  \
# 0  1.125174e+05  1.002778e+05  2.038915e+04  3.053853e+04  8.395911e+04  ...
# 1 -4.749764e+06 -4.749764e+06  1.147556e+07  1.147556e+07  1.272055e+07  ...
# 2  1.477503e+06  1.477503e+06  3.904086e+05  3.904086e+05  4.979106e+05  ...
# 3  1.318250e+04  1.318250e+04  8.650108e+04  8.650108e+04  5.896693e+03  ...
# 4  3.046536e+05  3.046536e+05  2.528307e+05  2.528307e+05  3.034449e+05  ...
#
#    Col2388  Col2389  Col2390  Col2391  Col2392  Col2393  Col2394  Col2395  \
# ...

# %% [markdown]
# # data preprocessing and cleaning

# %%
#find the null values for train data
bdata.isnull().sum()
# Out:
# Col1           0
# Col2           0
# Col3           0
# Col4           0
# Col5           0
# Col6           0
# Col7           0
# Col8           0
# Col9           0
# Col10          0
# Col11          0
# Col12          0
# Col13       1249
# Col14       1244
# Col15       1246
# Col16       1243
# Col17       1470
# Col18       2860
# Col19      14759
# Col20      14319
# Col21       1241
# Col22       1244
# Col23       1243
# Col24       1246
# Col25          0
# Col26          0
# Col27        682
# Col28      12260
# Col29          0
# Col30          0
#            ...
# Col2368        0
# Col2369        0
# Col2370        0
# Col2371        0
# Col2372        0
# Col2373        0
# Col2374        0
# Col2375        0
# Col2376        0
# Col2377        0
# Col2378        0
# Col2379        0
# Col2380        0
# Col2381        0
# Col2382        0
# Col2383        0
# Col2384        0
# Col2385        0
# Col2386        0
# Col2387        0
# Col2388        0
# ...

# %%
#find the null values of the test data
# Col2384    0
# Col2385    0
# Col2386    0
# Col2387    0
# Col2388    0
# Col2389    0
# Col2390    0
# Col2391    0
# Col2392    0
# Col2393    0
# Col2394    0
# Col2395    0
# Col2396    0
# Col2397    0
# Length: 2395, dtype: int64

# %%
#fill null values of test data with mean
testdata.fillna(testdata.mean(),inplace=True)

# %%
testdata.head()
# Out:
#         Col1          Col3          Col4          Col5          Col6  \
# 0  RIGD58ZWD  8.167140e+04  8.614542e+04  7.532296e+04  7.532296e+04
# 1  RIH660YDS -1.362824e+07 -4.493043e+06 -3.777257e+06 -4.493043e+06
# 2  RIH660Q96  1.302700e+06  1.341449e+06  1.240085e+06  1.341449e+06
# 3  RIYDO15W1  1.932258e+05  1.454433e+05  1.929148e+05  1.454433e+05
# 4  RIYBGC1ZD  3.913385e+05  1.987337e+05  1.703432e+05  1.987337e+05
#
#            Col7          Col8          Col9         Col10         Col11  ...  \
# 0  1.125174e+05  1.002778e+05  2.038915e+04  3.053853e+04  8.395911e+04  ...
# 1 -4.749764e+06 -4.749764e+06  1.147556e+07  1.147556e+07  1.272055e+07  ...
# 2  1.477503e+06  1.477503e+06  3.904086e+05  3.904086e+05  4.979106e+05  ...
# 3  1.318250e+04  1.318250e+04  8.650108e+04  8.650108e+04  5.896693e+03  ...
# 4  3.046536e+05  3.046536e+05  2.528307e+05  2.528307e+05  3.034449e+05  ...
#
#    Col2388  Col2389  Col2390  Col2391  Col2392  Col2393  Col2394  Col2395  \
# ...

# %%
testdata.isnull().sum()
# Out:
# Col1       0
# Col3       0
# Col4       0
# Col5       0
# Col6       0
# Col7       0
# Col8       0
# Col9       0
# Col10      0
# Col11      0
# Col12      0
# Col13      0
# Col14      0
# Col15      0
# Col16      0
# Col17      0
# Col18      0
# Col19      0
# Col20      0
# Col21      0
# Col22      0
# Col23      0
# Col24      0
# Col25      0
# Col26      0
# Col27      0
# Col28      0
# Col29      0
# Col30      0
# Col31      0
#           ..
# Col2368    0
# Col2369    0
# Col2370    0
# Col2371    0
# Col2372    0
# Col2373    0
# Col2374    0
# Col2375    0
# Col2376    0
# Col2377    0
# Col2378    0
# Col2379    0
# Col2380    0
# Col2381    0
# Col2382    0
# Col2383    0
# Col2384    0
# Col2385    0
# Col2386    0
# Col2387    0
# Col2388    0
# Col2389    0
# Col2390    0
# Col2391    0
# Col2392    0
# Col2393    0
# Col2394    0
# Col2395    0
# Col2396    0
# Col2397    0
# Length: 2394, dtype: int64

# %%
a=bdata.dtypes.reset_index()
a.columns = ['name','dtype']

# %%
#three columns are in object form they should be converted to float or drop  in train data
a.groupby(['dtype']).sum()
# Out:
#                                                       name
# dtype
# int64    Col2Col29Col30Col31Col32Col33Col34Col35Col36Co...
# float64  Col3Col4Col5Col6Col7Col8Col9Col10Col11Col12Col...
# object                                    Col1Col747Col836

# %%
bdata.drop(['Col1','Col747','Col836','Col702','Col733','Col742','Col754','Col763','Col791','Col813','Col822','Col831','Col843','Col852'],axis=1,inplace=True)

# %%
x=testdata.dtypes.reset_index()
x.columns=['name','dtype']

# %%
#in test data 13 columns are in object and they need to drop
y=x.groupby(['dtype']).sum()
y
# Out:
#                                                       name
# dtype
# int64    Col29Col30Col31Col32Col33Col34Col35Col36Col44C...
# float64  Col3Col4Col5Col6Col7Col8Col9Col10Col11Col12Col...
# object   Col1Col702Col733Col742Col754Col763Col791Col813...

# %%
y.values
# Out:
# array([['...'],
#        ['...'],
#        ['Col1Col702Col733Col742Col754Col763Col791Col813Col822Col831Col843Col852']],
#       dtype=object)

# %%
testdata.drop(['Col1','Col747','Col836','Col702','Col733','Col742','Col754','Col763','Col791','Col813','Col822','Col831','Col843','Col852'],axis=1,inplace=True)

# %%
bdata.head()
# Out:
#    Col2          Col3          Col4          Col5          Col6          Col7  \
# 0     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04  5.273655e+03
# 1     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05  2.154519e+05
# 2     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07  1.879882e+07
# 3     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05  8.257254e+05
# 4     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06  2.583183e+06
#
#            Col8          Col9         Col10         Col11  ...  Col2388  \
# 0  2.346153e+04  1.285597e+04  2.871509e+04  9.114586e+03  ...        0
# 1  1.923615e+05  1.726538e+05  1.666974e+05  2.013518e+05  ...        0
# 2  1.514035e+07  5.320778e+06  6.906324e+06  9.368338e+06  ...        0
# 3  7.605803e+05  3.577134e+05  4.236612e+05  4.304848e+05  ...        0
# 4  2.086546e+06  5.938358e+06  5.446532e+06  3.473444e+06  ...        0
#
# ...

# %%
testdata.head()
# Out:
#            Col3          Col4          Col5          Col6          Col7  \
# 0  8.167140e+04  8.614542e+04  7.532296e+04  7.532296e+04  1.125174e+05
# 1 -1.362824e+07 -4.493043e+06 -3.777257e+06 -4.493043e+06 -4.749764e+06
# 2  1.302700e+06  1.341449e+06  1.240085e+06  1.341449e+06  1.477503e+06
# 3  1.932258e+05  1.454433e+05  1.929148e+05  1.454433e+05  1.318250e+04
# 4  3.913385e+05  1.987337e+05  1.703432e+05  1.987337e+05  3.046536e+05
#
#            Col8          Col9         Col10         Col11         Col12  ...  \
# 0  1.002778e+05  2.038915e+04  3.053853e+04  8.395911e+04  8.138800e+04  ...
# 1 -4.749764e+06  1.147556e+07  1.147556e+07  1.272055e+07  1.272055e+07  ...
# 2  1.477503e+06  3.904086e+05  3.904086e+05  4.979106e+05  4.979106e+05  ...
# 3  1.318250e+04  8.650108e+04  8.650108e+04  5.896693e+03  5.896693e+03  ...
# 4  3.046536e+05  2.528307e+05  2.528307e+05  3.034449e+05  3.034449e+05  ...
#
# ...

# %%
hdfctest=testdata[['Col636',
 'Col649',
 'Col874',
 'Col875',
 'Col264',
 'Col872',
 'Col440',
 'Col633',
 'Col666',
 'Col1830',
 'Col92',
 'Col22',
 'Col627',
 'Col912',
 'Col476',
 'Col792',
 'Col291',
 'Col177',
 'Col26',
 'Col27',
 'Col178',
 'Col107',
 'Col460',
 'Col575',
 'Col25',
 'Col703',
 'Col681',
 'Col180',
 'Col21',
 'Col10',
 'Col28',
 'Col863',
 'Col932',
 'Col165',
 'Col683',
 'Col864',
 'Col83',
 'Col601',
 'Col466',
 'Col175',
 'Col15',
 'Col722',
 'Col886',
 'Col885',
 'Col621',
 'Col881',
 'Col172',
 'Col139',
 'Col405',
 'Col390',
 'Col891',
 'Col166',
 'Col614',
 'Col713',
 'Col499',
 'Col461',
 'Col795',
 'Col1301',
 'Col2051',
 'Col82',
 'Col910',
 'Col413',
 'Col375',
 'Col318',
 'Col1578',
 'Col1641',
 'Col2131',
 'Col569',
 'Col239',
 'Col50',
 'Col538',
 'Col1589',
 'Col826',
 'Col414',
 'Col1240',
 'Col348',
 'Col1959',
 'Col738',
 'Col778',
 'Col612',
 'Col2335',
 'Col227',
 'Col1178',
 'Col1313',
 'Col810',
 'Col1684',
 'Col1238',
 'Col1075',
 'Col2009',
 'Col2377',
 'Col844',
 'Col1685',
 'Col2104',
 'Col1211',
 'Col469',
 'Col45',
 'Col1616',
 'Col870',
 'Col963',
 'Col58',
 'Col1259',
 'Col580',
 'Col1429',
 'Col269',
 'Col103',
 'Col1530',
 'Col1635',
 'Col1570',
 'Col494',
 'Col352',
 'Col1042',
 'Col31',
 'Col1149',
 'Col1309',
 'Col971',
 'Col1848',
 'Col1923',
 'Col812',
 'Col1803',
 'Col519',
 'Col1717',
 'Col370',
 'Col2245',
 'Col2165',
 'Col225',
 'Col432',
 'Col1026',
 'Col922',
 'Col1480',
 'Col1475',
 'Col226',
 'Col2187',
 'Col1045',
 'Col1400',
 'Col1845',
 'Col1790',
 'Col1750',
 'Col425',
 'Col1643',
 'Col1772',
 'Col884',
 'Col629',
 'Col261',
 'Col593',
 'Col2368',
 'Col717']]

# %%
hdfctest
# Out:
#          Col636   Col649    Col874    Col875    Col264     Col872    Col440  \
# 0      0.000000  0.00000  1.325191  1.320985  1.745953  12.110928  0.000000
# 1      2.526330  0.00050  3.140282  3.140282  1.034075   7.833333  2.460771
# 2      0.005118  0.00000  1.375441  1.080582  1.722521  57.000000  0.003106
# 3      0.000000  0.00000  0.625706  0.625706  2.645751  12.110928  0.000000
# 4      0.000000  0.00000  1.892678  1.892678  2.645752  12.110928  0.000000
# 5      2.526330  0.00000  2.790756  2.790756  2.645751  12.110928  2.460771
# 6      0.002751  0.00000  1.512590  1.512590  1.745953  17.800000  0.002407
# 7      0.840843  0.00000  0.934106  0.934106  1.554839   5.320000  1.064269
# 8      0.000000  0.40151  1.325191  1.320985  1.745953   0.000000  0.132580
# 9      0.031353  0.00000  1.183540  0.564269  1.914854  65.500000  0.012529
# 10     0.000000  0.00000  1.782849  1.782849  2.557300  12.110928  0.000000
# ...

# %%
x=hdfctest.dtypes.reset_index()
x.columns=['name','dtype']

# %%
y=x.groupby(['dtype']).sum()
y
# Out:
#                                                       name
# dtype
# int64    Col1830Col83Col1917Col59Col1856Col134Col1166Co...
# float64  Col636Col649Col874Col875Col264Col872Col440Col6...

# %%
y.values
# Out:
# array([['...'],
#        ['...']],
#       dtype=object)

# %%
hdfctest
# Out:
#          Col636   Col649    Col874    Col875    Col264     Col872    Col440  \
# 0      0.000000  0.00000  1.325191  1.320985  1.745953  12.110928  0.000000
# 1      2.526330  0.00050  3.140282  3.140282  1.034075   7.833333  2.460771
# 2      0.005118  0.00000  1.375441  1.080582  1.722521  57.000000  0.003106
# 3      0.000000  0.00000  0.625706  0.625706  2.645751  12.110928  0.000000
# 4      0.000000  0.00000  1.892678  1.892678  2.645752  12.110928  0.000000
# 5      2.526330  0.00000  2.790756  2.790756  2.645751  12.110928  2.460771
# 6      0.002751  0.00000  1.512590  1.512590  1.745953  17.800000  0.002407
# 7      0.840843  0.00000  0.934106  0.934106  1.554839   5.320000  1.064269
# 8      0.000000  0.40151  1.325191  1.320985  1.745953   0.000000  0.132580
# 9      0.031353  0.00000  1.183540  0.564269  1.914854  65.500000  0.012529
# 10     0.000000  0.00000  1.782849  1.782849  2.557300  12.110928  0.000000
# ...

# %% [markdown]
# # decision tree model

# %%
from sklearn import tree

# %%
ctree=tree.DecisionTreeClassifier()

# %%
x=bdata.drop('Col2',axis=1)
y=bdata['Col2']

# %%
ctree.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# # feature importance for the model or you can use the PCA method also

# %%
ctree.feature_importances_
# Out:
# array([1.92078651e-03, 0.00000000e+00, 3.40316463e-04, ...,
#        1.23194048e-03, 1.02094939e-03, 1.25275462e-05])

# %%
comp_df = pd.DataFrame()
comp_df['cols'] = x.columns
comp_df['imp'] = ctree.feature_importances_*100

comp_df
# Out:
#          cols       imp
# 0        Col3  0.192079
# 1        Col4  0.000000
# 2        Col5  0.034032
# 3        Col6  0.117652
# 4        Col7  0.000000
# 5        Col8  0.218370
# 6        Col9  0.105705
# 7       Col10  0.564975
# 8       Col11  0.290835
# 9       Col12  0.224779
# 10      Col13  0.031249
# 11      Col14  0.000000
# 12      Col15  0.193598
# 13      Col16  0.000000
# 14      Col17  0.445827
# 15      Col18  0.219532
# 16      Col19  0.113679
# 17      Col20  0.156234
# 18      Col21  0.355077
# 19      Col22  0.541575
# 20      Col23  0.232063
# 21      Col24  0.449017
# 22      Col25  0.406505
# 23      Col26  0.674353
# 24      Col27  0.206111
# 25      Col28  0.598888
# 26      Col29  0.071681
# 27      Col30  0.000000
# 28      Col31  0.050845
# 29      Col32  0.000000
# ...       ...       ...
# 2350  Col2368  0.034032
# 2351  Col2369  0.000000
# 2352  Col2370  0.000000
# 2353  Col2371  0.045376
# 2354  Col2372  0.000000
# 2355  Col2373  0.000000
# ...

# %%
a=comp_df.sort_values('imp',ascending=False)

# %%
a
# Out:
#          cols       imp
# 633    Col636  3.040476
# 646    Col649  1.523165
# 858    Col874  1.413117
# 23      Col26  0.674353
# 458    Col461  0.656692
# 663    Col666  0.650220
# 859    Col875  0.625756
# 611    Col614  0.599857
# 25      Col28  0.598888
# 1812  Col1830  0.582877
# 856    Col872  0.573416
# 174    Col177  0.569085
# 561    Col564  0.568936
# 7       Col10  0.564975
# 709    Col713  0.546639
# 896    Col912  0.545337
# 19      Col22  0.541575
# 177    Col180  0.535271
# 869    Col885  0.516784
# 343    Col346  0.509766
# 680    Col683  0.507586
# 437    Col440  0.483127
# 410    Col413  0.465633
# 630    Col633  0.452701
# 572    Col575  0.450464
# 21      Col24  0.449017
# 14      Col17  0.445827
# 712    Col716  0.441591
# 1260  Col1276  0.439489
# 160    Col163  0.438554
# ...       ...       ...
# 1250  Col1266  0.000000
# 353    Col356  0.000000
# 1248  Col1264  0.000000
# 1247  Col1263  0.000000
# 1269  Col1285  0.000000
# 1270  Col1286  0.000000
# ...

# %%
a=a.head(580)

# %%
a.imp.sum()
# Out:
# 95.39418797020326

# %%
#convert to list
a['cols'].tolist()
# Out:
# ['Col636',
#  'Col649',
#  'Col874',
#  'Col26',
#  'Col461',
#  'Col666',
#  'Col875',
#  'Col614',
#  'Col28',
#  'Col1830',
#  'Col872',
#  'Col177',
#  'Col564',
#  'Col10',
#  'Col713',
#  'Col912',
#  'Col22',
#  'Col180',
#  'Col885',
#  'Col346',
#  'Col683',
#  'Col440',
#  'Col413',
#  'Col633',
#  'Col575',
#  'Col24',
#  'Col17',
#  'Col716',
#  'Col1276',
#  'Col163',
#  'Col881',
#  'Col467',
#  'Col25',
#  'Col627',
#  'Col92',
#  'Col409',
#  'Col876',
#  'Col264',
#  'Col476',
#  'Col700',
#  'Col680',
#  'Col178',
#  'Col759',
#  'Col162',
#  'Col107',
#  'Col638',
#  'Col21',
#  'Col863',
#  'Col42',
#  'Col814',
#  'Col926',
#  'Col43',
#  'Col771',
#  'Col586',
#  'Col932',
#  'Col174',
#  'Col390',
#  'Col134',
#  'Col286',
#  'Col182',
#  'Col196',
#  'Col393',
#  'Col176',
#  'Col873',
#  'Col802',
#  'Col1707',
#  'Col155',
#  'Col736',
#  'Col37',
#  'Col884',
#  'Col93',
#  'Col150',
#  'Col579',
#  'Col473',
#  'Col75',
#  'Col11',
#  'Col916',
# ...

# %%
#take x 
x=bdata[['Col636',
 'Col649',
 'Col874',
 'Col875',
 'Col264',
 'Col872',
 'Col440',
 'Col633',
 'Col666',
 'Col1830',
 'Col92',
 'Col22',
 'Col627',
 'Col912',
 'Col476',
 'Col792',
 'Col291',
 'Col177',
 'Col26',
 'Col27',
 'Col178',
 'Col107',
 'Col460',
 'Col575',
 'Col25',
 'Col703',
 'Col681',
 'Col180',
 'Col21',
 'Col10',
 'Col28',
 'Col863',
 'Col932',
 'Col165',
 'Col683',
 'Col864',
 'Col83',
 'Col601',
 'Col466',
 'Col175',
 'Col15',
 'Col722',
 'Col886',
 'Col885',
 'Col621',
 'Col881',
 'Col172',
 'Col139',
 'Col405',
 'Col390',
 'Col891',
 'Col166',
 'Col614',
 'Col713',
 'Col499',
 'Col461',
 'Col795',
 'Col1917',
 'Col786',
 'Col802',
 'Col322',
 'Col277',
 'Col164',
 'Col9',
 'Col212',
 'Col12',
 'Col604',
 'Col877',
 'Col59',
 'Col1856',
 'Col719',
 'Col882',
 'Col652',
 'Col923',
 'Col106',
 'Col37',
 'Col880',
 'Col186',
 'Col586',
 'Col416',
 'Col134',
 'Col93',
 'Col467',
 'Col141',
 'Col241',
 'Col343',
 'Col1166',
 'Col270',
 'Col682',
 'Col1781',
 'Col182',
 'Col564',
 'Col851',
 'Col24',
 'Col930',
 'Col150',
 'Col148',
 'Col208',
 'Col510',
 'Col876',
 'Col723',
 'Col193',
 'Col43',
 'Col255',
 'Col780',
 'Col346',
 'Col355',
 'Col483',
 'Col39',
 'Col759',
 'Col638',
 'Col543',
 'Col986',
 'Col793',
 'Col618',
 'Col676',
 'Col104',
 'Col243',
 'Col1730',
 'Col215',
 'Col147',
 'Col69',
 'Col1987',
 'Col552',
 'Col727',
 'Col305',
 'Col2165',
 'Col225',
 'Col432',
 'Col1026',
 'Col922',
 'Col1480',
 'Col1475',
 'Col226',
 'Col2187',
 'Col1045',
 'Col1400',
 'Col1845',
 'Col1790',
 'Col1750',
 'Col425',
 'Col1643',
 'Col1772',
 'Col884',
 'Col629',
 'Col261',
 'Col593',
 'Col2368',
 'Col717']]

# %%
#take y
y=bdata['Col2']

# %%
#fit x and y
ctree.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn import tree

# %%
from sklearn.ensemble import RandomForestClassifier
rf_tree=RandomForestClassifier(n_estimators=100)

# %%
rf_tree.fit(x,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=22)

# %%
rf_tree.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_test_pred=rf_tree.predict(x_test)

# %%
from sklearn import metrics

# %%
#acuuracy of the model
metrics.accuracy_score(y_test,y_test_pred)

# %% [markdown]
# ### random forest model

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rf_tree=RandomForestClassifier(n_estimators=100)
param_grid={'n_estimators':[100,500],
            'criterion'   :['gini','entropy'],
            'max_features' :[300,400,455],
            'max_depth'    :[16,22,34,45,56],
            'min_samples_leaf':[13,24],
           }

# %%
random_rf=RandomizedSearchCV(rf_tree,n_iter=10,param_distributions=param_grid,scoring="accuracy",verbose=2, cv=4)
random_rf.fit(x_train,y_train)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# [CV] n_estimators=100, min_samples_leaf=13, max_features=300, max_depth=16, criterion=entropy
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=100, min_samples_leaf=13, max_features=300, max_depth=16, criterion=entropy, total= 1.7min
# [CV] n_estimators=100, min_samples_leaf=13, max_features=300, max_depth=16, criterion=entropy
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.7min remaining:    0.0s
# [CV]  n_estimators=100, min_samples_leaf=13, max_features=300, max_depth=16, criterion=entropy, total= 1.7min
# [CV] n_estimators=100, min_samples_leaf=13, max_features=300, max_depth=16, criterion=entropy
# [CV]  n_estimators=100, min_samples_leaf=13, max_features=300, max_depth=16, criterion=entropy, total= 1.8min
# [CV] n_estimators=100, min_samples_leaf=13, max_features=300, max_depth=16, criterion=entropy
# ...

# %%
random_final_model=random_rf.best_estimator_
y_pred=random_final_model.predict(x_test)
metrics.accuracy_score(y_pred, y_test)

# %%
#accuracy after tuning the model
metrics.recall_score(y_test,y_test_pred)

# %%
from sklearn.metrics import f1_score

# %%
random_rf=RandomizedSearchCV(rf_tree,n_iter=10,param_distributions=param_grid,scoring="f1",verbose=2, cv=4)
random_rf.fit(x_train,y_train)

# %%
metrics.f1_score(y_test, y_test_pred)

# %%
f1_score(y_test,y_test_pred)

# %%
rf_tree.fit(x_train,y_train)

# %% [markdown]
# ### predict the model with given test data (hdfc test)

# %%
hdfc_hackathon=rf_tree.predict(hdfctest)

# %%
hdfc_prediction=hdfc_hackathon.tolist()

# %%
hdfc_prediction.count(0)+hdfc_prediction.count(1)

# %%
print(hdfc_prediction)

# %%
type('hdfc_prediction[0]')

# %%
#convert tolist to data frame
df=pd.DataFrame(hdfc_prediction)

# %%
df.head()

# %%
#load the predicte test data
tdata=pd.read_csv('Test.csv')

# %%
tdata.head()

# %%
colid=tdata.Col1.values.tolist()

# %%
colid

# %% [markdown]
# ### make the submission file

# %%
df=pd.DataFrame()
df['Col1']=colid
df['Col2']=hdfc_prediction
df.head()

# %%
print(colid)

# %%
#final submission file 
df.to_csv('HDFC_final.csv',index=None)
